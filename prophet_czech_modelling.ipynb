# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pylab import rcParams
from sklearn.model_selection import TimeSeriesSplit
import holidays
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric
from statsmodels.tools.eval_measures import rmse
from prophet.plot import add_changepoints_to_plot
# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_cleaned.csv', parse_dates=['date'])

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Time Series Creation Functions

# %%
def select_series(data, time_period='day', revenue='net'):
    time_periods = {
        'day': 'D',
        'week': 'W',
        'month': 'M'}
    
    revenue_cat = {
        'net':'net_revenue',
        'gross':'gross_revenue',
        'profit':'net_profit'}
    
    data = data.set_index('date')
    data = data[revenue_cat[revenue]].resample(time_periods[time_period]).sum()
    data = pd.DataFrame(data).reset_index()
    return data

# %%
def create_ts_dt_feat(ts_df):
    ts_df['year'] = ts_df['date'].dt.year
    ts_df['month'] = ts_df['date'].dt.month
    ts_df['day'] = ts_df['date'].dt.day
    ts_df['weekofyear'] = ts_df['date'].dt.week
    ts_df['weekday'] = ts_df['date'].dt.weekday
    ts_df['weekday'] = np.where(ts_df.weekday == 0, 7, ts_df.weekday)
    return ts_df

# %%
def create_ts_lag_feat(ts_df, start, n_lag):
    for lag in range(start, n_lag+1):
        ts_df[f'lag_{lag}'] = ts_df.iloc[:, 1].shift(lag)
    ts_df = ts_df.iloc[n_lag: , :]
    return ts_df

# %%
def create_month_revenue_plot_per_cat(df, coltype, catlist):
    df_list = []
    for cat in catlist:
        tmp = df[df[coltype] == cat]
        tmp = select_series(tmp, 'month', 'net')
        tmp[coltype] = cat
        df_list.append(tmp)
    final_df = pd.concat(df_list).reset_index()
    sns.lineplot(data=final_df, x="date", y="net_revenue", hue=f"{coltype}")
    return final_df

# %% [markdown]
# ## Data Prep and Feature Engineering

# %%
filters = df['country'] == 'Czech Republic'
df = df[filters]

# %%
df=select_series(df, 'day', 'net')

# %%
df.columns=['ds', 'y']

# %%
train = df[df['ds'] < pd.Timestamp('2021-06-01')]
test = df[df['ds'] >= pd.Timestamp('2021-06-01')]

# %%
print(f"Train date range: {train['ds'].min()} to {train['ds'].max()}")
# Out:
# Train date range: 2019-06-01 00:00:00 to 2021-05-31 00:00:00

# %%
print(f"Test date range: {test['ds'].min()} to {test['ds'].max()}")
# Out:
# Test date range: 2021-06-01 00:00:00 to 2022-01-14 00:00:00

# %% [markdown]
# ## Prophet Initial Model

# %%
m = Prophet(daily_seasonality=False)
m.add_country_holidays(country_name='CZ')
m.fit(train)

# %%
future=m.make_future_dataframe(periods=240, freq='D')
forecast=m.predict(future)
fig=m.plot(forecast)

# %%
predictions = forecast.iloc[-len(test):]['yhat']
actuals = test['y']

print(f"RMSE: {round(rmse(predictions, actuals))}")
# Out:
# RMSE: 13318

# %%
# plot change points
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)

# %% [markdown]
# ## Cross Validation

# %%
cutoffs=pd.to_datetime(['2021-06-01'])
#cutoffs=cutoffs
df_cv = cross_validation(m, initial='365.25 days', period='30 days', horizon = '240 days', parallel='processes')
# Out:
# INFO:prophet:Making 5 forecasts with cutoffs between 2020-06-05 00:00:00 and 2020-10-03 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa517ddbb0>

# %%
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon           mse         rmse          mae      mape     mdape  \
# 0 24 days  1.781777e+07  4221.109917  3602.133116  0.288510  0.261868
# 1 25 days  2.076155e+07  4556.484482  3826.621073  0.299654  0.269305
# 2 26 days  2.203238e+07  4693.866014  3975.148965  0.311092  0.279078
# 3 27 days  2.382346e+07  4880.928661  4152.223154  0.324769  0.285622
# 4 28 days  2.493824e+07  4993.820171  4231.078560  0.328815  0.287399
#
#       smape  coverage
# 0  0.269865  0.691667
# 1  0.285272  0.683333
# 2  0.296652  0.650000
# 3  0.311652  0.625000
# 4  0.320146  0.608333

# %%
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %%
fig=m.plot_components(forecast)

# %% [markdown]
# ## Hyperparameter Tuning

# %%
import itertools

param_grid = {'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
              'seasonality_prior_scale': [0.01, 0.02, 0.1, 1.0, 10.0],
              'seasonality_mode': ['additive', 'multiplicative'],
             'holidays_prior_scale': [0.01, 0.1, 1.0, 10.0]}

# generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # store the RMSEs for each params here

# %%
# go through all parameter combos
for i in range(len(all_params)):
  
    # create & fit model with given params combo
    m = Prophet(daily_seasonality=False, **all_params[i]).add_country_holidays(country_name='CZ').fit(df)
    
    # cross validate the model 
    df_cv = cross_validation(m, 
                             horizon="240 days",
                             period="30 days", 
                             initial="365.25 days", 
                             parallel="processes")
    
    df_p = performance_metrics(df_cv, rolling_window=1)
    # pull rmse and add it to the list
    rmses.append(df_p['rmse'].values[0])
# Out:
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa880f71c0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f130400>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa882acd60>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec454c0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4de49dc0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa8828dd90>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc5fe20>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f1362b0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa7900c910>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f293310>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50fcdf70>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f126040>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec452e0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec1ea90>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4de28a00>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f132190>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56c20970>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4de49dc0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f124a90>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51375cd0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f2cbb80>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa55f3f580>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f292250>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51c202e0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51378d00>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec452e0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88449700>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec1ea90>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79340>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f132160>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88449700>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec454c0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc5fe20>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50fcd820>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79430>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa517dd6d0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa7900c910>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa881e4e50>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa565c8fa0>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa55294fa0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc890d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552ce220>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa7900c910>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc68bb0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505625e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5529a820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4edf8040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5529a820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4edf8040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552ca460>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50574700>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad32b0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad1160>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79430>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a4c40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dafbe0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51db6130>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad19a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5055e040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4edf8040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad4f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50574940>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51af8760>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56422640>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51d90640>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552cab50>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552ce220>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552bd3d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad12e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51d9bdf0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50e17160>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50576040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec3afa0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a4c40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50565820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552cab50>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f14e400>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5529aca0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5055e5e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51c36820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50576040>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dbe400>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad4f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc63df0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50e17160>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec3bf70>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc54940>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4f148be0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50586b80>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51db79a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552afa60>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ae00a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505714c0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79430>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51af0df0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec431f0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dbe880>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505714c0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa565c8a90>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa565c8a90>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79430>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50574b80>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50574b80>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dbc400>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc562b0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51af83d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc72730>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50562820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50e17160>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505744c0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a9910>
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc68100>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505693a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50562820>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dbed00>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51da7400>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50569fa0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56442ac0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc54a60>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5641bd00>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec20a00>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5529a0d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56425f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79430>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51db6be0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad4f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc684f0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552af700>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa505885e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4ec208e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a90a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51daddf0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51db5f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51d94d30>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad4f40>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51363fa0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552af700>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a90a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc70700>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51af04f0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a90a0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51dc7100>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa4dc83700>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa88451f10>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa51ad0610>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56c20970>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5167e0d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa5167e0d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56b79340>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552a9a60>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa7a0842e0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa552af0d0>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50565b80>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa56425880>
# INFO:prophet:Making 12 forecasts with cutoffs between 2020-06-23 00:00:00 and 2021-05-19 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7faa50588280>

# %%
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
best_params= all_params[np.argmin(rmses)]
print(best_params)
# Out:
# {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'holidays_prior_scale': 0.01}

# %% [markdown]
# ## Best Model

# %%
final_m=Prophet(daily_seasonality=False, seasonality_mode='multiplicative', 
                    seasonality_prior_scale=0.1, changepoint_prior_scale=0.001, holidays_prior_scale= 0.01)
final_m.fit(train)

# %%
final_future=final_m.make_future_dataframe(periods=240, freq='D')
final_forecast=final_m.predict(final_future)
fig=final_m.plot(final_forecast)

# %% [markdown]
# ## Best Model Visualization

# %%
fig, ax=plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(15)


final_m.plot(final_forecast, ax=ax)
ax.plot(test.ds, test.y, color='r', label='Test')
ax.plot(train.ds, train.y, color='black', label='Train')
plt.legend()
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
# Out:
# Text(92.625, 0.5, 'Sales')

# %%
x_test_forecast=final_m.predict(test)

f, ax = plt.subplots(figsize=(14, 5))
f.set_figheight(5)
f.set_figwidth(15)
test.plot(x='ds', y='y', color='r', label='Actual', ax=ax)
x_test_forecast.plot(x='ds', y='yhat', label='Forecast', ax=ax)
plt.legend()
ax.set_xlabel('Date')
ax.set_ylabel('Sales')
plt.title('Forecast VS Actual Daily Sales')
# Out:
# Text(0.5, 1.0, 'Forecast VS Actual Daily Sales')

# %%
predictions = final_forecast.iloc[-len(test):]['yhat']
actuals = test['y']

print(f"RMSE: {round(rmse(predictions, actuals))}")
# Out:
# RMSE: 12245

# %%
# import json
# from prophet.serialize import model_to_json, model_from_json

# # Save model
# with open('serialized_model.json', 'w') as fout:
#     json.dump(model_to_json(m), fout)

# # Load model
# with open('serialized_model.json', 'r') as fin:
#     m = model_from_json(json.load(fin))

# %% [markdown]
# ## Miscellaneous Final plots

# %%
fig, ax = plt.subplots(1)
fig.set_figheight(5)
fig.set_figwidth(15)
ax.plot(df['ds'], df['y'], color='b', label='actual')
ax.plot(forecast['ds'], forecast['yhat'], color='g', label='initial')
ax.plot(final_forecast['ds'], final_forecast['yhat'], color='r', label='final')
ax.set_xbound(lower=dt.date(2021,9,1), upper=dt.date(2021,9,30))
plt.legend()
plt.title('One Month Forecast Vs Actual, March 1 to 30, 2021')
# Out:
# Text(0.5, 1.0, 'One Month Forecast Vs Actual, March 1 to 30, 2021')

# %%
fig, ax = plt.subplots(1)
fig.set_figheight(5)
fig.set_figwidth(15)
ax.plot(df['ds'], df['y'], color='b', label='actual')
ax.plot(forecast['ds'], forecast['yhat'], color='g', label='initial')
ax.plot(final_forecast['ds'], final_forecast['yhat'], color='r', label='predicted')
ax.set_xbound(lower=dt.date(2021,11,1), upper=dt.date(2021,12,31))
plt.legend()
plt.title('One Month Forecast Vs Actual, March 1 to 30, 2021')
# Out:
# Text(0.5, 1.0, 'One Month Forecast Vs Actual, March 1 to 30, 2021')
